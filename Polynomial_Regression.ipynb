# %% [markdown]
# <a href="https://colab.research.google.com/github/neelima-singh07/Machine-Learning-/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing dataset

# %%
data=pd.read_csv('/content/age_vs_rbc_dataset_extended.csv')
data
# Out:
#     Age  RBC's (in billions)
# 0    10                 1481
# 1     5                  412
# 2    70                  701
# 3    21                 2680
# 4    75                  493
# 5    22                 2740
# 6    12                 1780
# 7    50                 1701
# 8    85                  809
# 9    15                 1191
# 10    4                  390
# 11   60                 1191
# 12   95                   21
# 13    1                   99
# 14   80                  291
# 15   82                  240
# 16   25                 2105
# 17   45                 2988
# 18   35                 2343
# 19   10                 1572
# 20   23                 2095
# 21   23                 2073
# 22   74                  319
# 23   61                 1169
# 24   72                  651
# 25    9                 1555
# 26    5                  537
# 27   14                 1941
# 28   87                  878
# 29   12                 1310
# 30   21                 2691
# ...

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values
print(X)
print()
print(y)
# Out:
# [[10]
#  [ 5]
#  [70]
#  [21]
#  [75]
#  [22]
#  [12]
#  [50]
#  [85]
#  [15]
#  [ 4]
#  [60]
#  [95]
#  [ 1]
#  [80]
#  [82]
#  [25]
#  [45]
#  [35]
#  [10]
#  [23]
#  [23]
#  [74]
#  [61]
#  [72]
#  [ 9]
#  [ 5]
#  [14]
#  [87]
#  [12]
#  [21]
#  [20]
#  [21]
#  [13]
#  [86]
#  [47]
#  [48]
#  [24]
#  [13]
#  [12]]
#
# [1481  412  701 2680  493 2740 1780 1701  809 1191  390 1191   21   99
#   291  240 2105 2988 2343 1572 2095 2073  319 1169  651 1555  537 1941
#   878 1310 2691 2604 2560 1347  692 3138 1601 1937 1017 1610]

# %% [markdown]
# # Training the whole dataset using Linear Regx

# %%
from sklearn.linear_model import LinearRegression

regressor=LinearRegression()
regressor.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Training  whole dataset using Polynomial Regx

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly_reg=PolynomialFeatures(degree=6)
X_poly=poly_reg.fit_transform(X)
regressor2=LinearRegression()
regressor2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X)

# %% [markdown]
# # Visualising Linear regx

# %%
plt.scatter(X,y,color='red')
plt.plot(X,regressor.predict(X),color='blue')
plt.title('Age vs RBC')
plt.xlabel('Age')
plt.ylabel('RBC')
plt.show()

# %% [markdown]
# # Visualising Polynomial regx

# %%
# Sort the X values for a smooth curve
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))

plt.scatter(X, y, color='red')
# Plot the polynomial regression line using the sorted X values
plt.plot(X_grid, regressor2.predict(poly_reg.fit_transform(X_grid)), color='blue')
plt.title('Age vs RBC (Polynomial Regression)')
plt.xlabel('Age')
plt.ylabel('RBC')
plt.show()
# Out:
# /tmp/ipython-input-28-4272456304.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
